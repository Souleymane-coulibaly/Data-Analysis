# %%
import pandas as pd

# %%
# lire le fichier csv dans un dataFrame
food_info = pd.read_csv("original.csv")

# %%
food_info
# Out:
#       NDB_No                   Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 0       1001            BUTTER WITH SALT      15.87         717         0.85
# 1       1002    BUTTER WHIPPED WITH SALT      15.87         717         0.85
# 2       1003        BUTTER OIL ANHYDROUS       0.24         876         0.28
# 3       1004                 CHEESE BLUE      42.41         353        21.40
# 4       1005                CHEESE BRICK      41.11         371        23.24
# ...      ...                         ...        ...         ...          ...
# 8613   83110             MACKEREL SALTED      43.00         305        18.50
# 8614   90240  SCALLOP (BAY&SEA) CKD STMD      70.25         111        20.54
# 8615   90480                  SYRUP CANE      26.00         269         0.00
# 8616   90560                   SNAIL RAW      79.20          90        16.10
# 8617   93600            TURTLE GREEN RAW      78.50          89        19.80
#
# ...

# %%
print(type(food_info))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# Head() retourner les premiers lignes par defaut 5 
food_info.head()
# Out:
#    NDB_No                 Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 0    1001          BUTTER WITH SALT      15.87         717         0.85
# 1    1002  BUTTER WHIPPED WITH SALT      15.87         717         0.85
# 2    1003      BUTTER OIL ANHYDROUS       0.24         876         0.28
# 3    1004               CHEESE BLUE      42.41         353        21.40
# 4    1005              CHEESE BRICK      41.11         371        23.24
#
#    Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  ...  \
# 0          81.11     2.11            0.06           0.0           0.06  ...
# 1          81.11     2.11            0.06           0.0           0.06  ...
# 2          99.48     0.00            0.00           0.0           0.00  ...
# 3          28.74     5.11            2.34           0.0           0.50  ...
# 4          29.68     3.18            2.79           0.0           0.51  ...
#
#    Vit_A_IU  Vit_A_RAE  Vit_E_(mg)  Vit_D_mcg  Vit_D_IU  Vit_K_(mcg)  \
# ...

# %%
# columns accéder à l'attribut complet de la colonne
column_names = food_info.columns
print(column_names)
# Out:
# Index(['NDB_No', 'Shrt_Desc', 'Water_(g)', 'Energ_Kcal', 'Protein_(g)',
#        'Lipid_Tot_(g)', 'Ash_(g)', 'Carbohydrt_(g)', 'Fiber_TD_(g)',
#        'Sugar_Tot_(g)', 'Calcium_(mg)', 'Iron_(mg)', 'Magnesium_(mg)',
#        'Phosphorus_(mg)', 'Potassium_(mg)', 'Sodium_(mg)', 'Zinc_(mg)',
#        'Copper_(mg)', 'Manganese_(mg)', 'Selenium_(mcg)', 'Vit_C_(mg)',
#        'Thiamin_(mg)', 'Riboflavin_(mg)', 'Niacin_(mg)', 'Vit_B6_(mg)',
#        'Vit_B12_(mcg)', 'Vit_A_IU', 'Vit_A_RAE', 'Vit_E_(mg)', 'Vit_D_mcg',
#        'Vit_D_IU', 'Vit_K_(mcg)', 'FA_Sat_(g)', 'FA_Mono_(g)', 'FA_Poly_(g)',
#        'Cholestrl_(mg)'],
#       dtype='object')

# %%
# Shape 
food_info.shape
# Out:
# (8618, 36)

# %%
# nombre de ligne 
num_rows = dimensions[0]
print(num_rows)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-13e5d719d85c> in <module>
#       1 # nombre de ligne
# ----> 2 num_rows = dimensions[0]
#       3 print(num_rows)
#
# NameError: name 'dimensions' is not defined

# %%
# Selection lignes loc[]
food_info.loc[6]
# Out:
# NDB_No                         1007
# Shrt_Desc          CHEESE CAMEMBERT
# Water_(g)                      51.8
# Energ_Kcal                      300
# Protein_(g)                    19.8
# Lipid_Tot_(g)                 24.26
# Ash_(g)                        3.68
# Carbohydrt_(g)                 0.46
# Fiber_TD_(g)                      0
# Sugar_Tot_(g)                  0.46
# Calcium_(mg)                    388
# Iron_(mg)                      0.33
# Magnesium_(mg)                   20
# Phosphorus_(mg)                 347
# Potassium_(mg)                  187
# Sodium_(mg)                     842
# Zinc_(mg)                      2.38
# Copper_(mg)                   0.021
# Manganese_(mg)                0.038
# Selenium_(mcg)                 14.5
# Vit_C_(mg)                        0
# Thiamin_(mg)                  0.028
# Riboflavin_(mg)               0.488
# Niacin_(mg)                    0.63
# Vit_B6_(mg)                   0.227
# Vit_B12_(mcg)                   1.3
# ...

# %%
type(food_info.loc[0])
# Out:
# pandas.core.series.Series

# %%
row_100 = food_info.loc[99]

# %%
print(row_100)
# Out:
# NDB_No                                  1111
# Shrt_Desc          MILK SHAKES THICK VANILLA
# Water_(g)                              74.45
# Energ_Kcal                               112
# Protein_(g)                             3.86
# Lipid_Tot_(g)                           3.03
# Ash_(g)                                 0.91
# Carbohydrt_(g)                         17.75
# Fiber_TD_(g)                               0
# Sugar_Tot_(g)                          17.75
# Calcium_(mg)                             146
# Iron_(mg)                                0.1
# Magnesium_(mg)                            12
# Phosphorus_(mg)                          115
# Potassium_(mg)                           183
# Sodium_(mg)                               95
# Zinc_(mg)                               0.39
# Copper_(mg)                            0.051
# Manganese_(mg)                         0.014
# Selenium_(mcg)                           2.3
# Vit_C_(mg)                                 0
# ...

# %%
# dataFrame contenant les lignes d'index 3, 4, 5, 6 
food_info.loc[3:6]
# Out:
#    NDB_No         Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 3    1004       CHEESE BLUE      42.41         353        21.40
# 4    1005      CHEESE BRICK      41.11         371        23.24
# 5    1006       CHEESE BRIE      48.42         334        20.75
# 6    1007  CHEESE CAMEMBERT      51.80         300        19.80
#
#    Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  ...  \
# 3          28.74     5.11            2.34           0.0           0.50  ...
# 4          29.68     3.18            2.79           0.0           0.51  ...
# 5          27.68     2.70            0.45           0.0           0.45  ...
# 6          24.26     3.68            0.46           0.0           0.46  ...
#
#    Vit_A_IU  Vit_A_RAE  Vit_E_(mg)  Vit_D_mcg  Vit_D_IU  Vit_K_(mcg)  \
# 3     721.0      198.0        0.25        0.5      21.0          2.4
# 4    1080.0      292.0        0.26        0.5      22.0          2.5
# ...

# %%
#DataFrame ligne  d'index 2,5, et 10 
#On créé une variable serie ( vecteur) avec ces index 
two_five_ten = [2,5,10]
food_info.loc[two_five_ten]
# Out:
#     NDB_No             Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 2     1003  BUTTER OIL ANHYDROUS       0.24         876         0.28
# 5     1006           CHEESE BRIE      48.42         334        20.75
# 10    1011          CHEESE COLBY      38.20         394        23.76
#
#     Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  ...  \
# 2           99.48     0.00            0.00           0.0           0.00  ...
# 5           27.68     2.70            0.45           0.0           0.45  ...
# 10          32.11     3.36            2.57           0.0           0.52  ...
#
#     Vit_A_IU  Vit_A_RAE  Vit_E_(mg)  Vit_D_mcg  Vit_D_IU  Vit_K_(mcg)  \
# 2     3069.0      840.0        2.80        1.8      73.0          8.6
# 5      592.0      174.0        0.24        0.5      20.0          2.3
# 10     994.0      264.0        0.28        0.6      24.0          2.7
#
#     FA_Sat_(g)  FA_Mono_(g)  FA_Poly_(g)  Cholestrl_(mg)
# ...

# %%
#DataFrame ligne  d'index 2,5, et 10 
food_info.loc[[2,5,10]]
# Out:
#     NDB_No             Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 2     1003  BUTTER OIL ANHYDROUS       0.24         876         0.28
# 5     1006           CHEESE BRIE      48.42         334        20.75
# 10    1011          CHEESE COLBY      38.20         394        23.76
#
#     Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  ...  \
# 2           99.48     0.00            0.00           0.0           0.00  ...
# 5           27.68     2.70            0.45           0.0           0.45  ...
# 10          32.11     3.36            2.57           0.0           0.52  ...
#
#     Vit_A_IU  Vit_A_RAE  Vit_E_(mg)  Vit_D_mcg  Vit_D_IU  Vit_K_(mcg)  \
# 2     3069.0      840.0        2.80        1.8      73.0          8.6
# 5      592.0      174.0        0.24        0.5      20.0          2.3
# 10     994.0      264.0        0.28        0.6      24.0          2.7
#
#     FA_Sat_(g)  FA_Mono_(g)  FA_Poly_(g)  Cholestrl_(mg)
# ...

# %%
last_row = food_info.loc[8613:8618]

# %%
last_row
# Out:
#       NDB_No                   Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 8613   83110             MACKEREL SALTED      43.00         305        18.50
# 8614   90240  SCALLOP (BAY&SEA) CKD STMD      70.25         111        20.54
# 8615   90480                  SYRUP CANE      26.00         269         0.00
# 8616   90560                   SNAIL RAW      79.20          90        16.10
# 8617   93600            TURTLE GREEN RAW      78.50          89        19.80
#
#       Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  \
# 8613          25.10    13.40            0.00           0.0            0.0
# 8614           0.84     2.97            5.41           0.0            0.0
# 8615           0.00     0.86           73.14           0.0           73.2
# 8616           1.40     1.30            2.00           0.0            0.0
# 8617           0.50     1.20            0.00           0.0            0.0
#
# ...

# %%
Cholesterol = food_info["Cholestrl_(mg)"]
Cholesterol
# Out:
# 0       215.0
# 1       219.0
# 2       256.0
# 3        75.0
# 4        94.0
#         ...
# 8613     95.0
# 8614     41.0
# 8615      0.0
# 8616     50.0
# 8617     50.0
# Name: Cholestrl_(mg), Length: 8618, dtype: float64

# %%
protein = food_info["Protein_(g)"]
protein
# Out:
# 0        0.85
# 1        0.85
# 2        0.28
# 3       21.40
# 4       23.24
#         ...
# 8613    18.50
# 8614    20.54
# 8615     0.00
# 8616    16.10
# 8617    19.80
# Name: Protein_(g), Length: 8618, dtype: float64

# %%
selenium_thiamin = food_info[["Shrt_Desc","Selenium_(mcg)","Thiamin_(mg)"]]
selenium_thiamin
# Out:
#                        Shrt_Desc  Selenium_(mcg)  Thiamin_(mg)
# 0               BUTTER WITH SALT             1.0         0.005
# 1       BUTTER WHIPPED WITH SALT             1.0         0.005
# 2           BUTTER OIL ANHYDROUS             0.0         0.001
# 3                    CHEESE BLUE            14.5         0.029
# 4                   CHEESE BRICK            14.5         0.014
# ...                          ...             ...           ...
# 8613             MACKEREL SALTED            73.4         0.020
# 8614  SCALLOP (BAY&SEA) CKD STMD            21.7         0.012
# 8615                  SYRUP CANE             0.7         0.130
# 8616                   SNAIL RAW            27.4         0.010
# 8617            TURTLE GREEN RAW            16.8         0.120
#
# [8618 rows x 3 columns]

# %%
import pandas as pd

# %%
food_info = pd.read_csv("original.csv")
food_info
# Out:
#       NDB_No                   Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 0       1001            BUTTER WITH SALT      15.87         717         0.85
# 1       1002    BUTTER WHIPPED WITH SALT      15.87         717         0.85
# 2       1003        BUTTER OIL ANHYDROUS       0.24         876         0.28
# 3       1004                 CHEESE BLUE      42.41         353        21.40
# 4       1005                CHEESE BRICK      41.11         371        23.24
# ...      ...                         ...        ...         ...          ...
# 8613   83110             MACKEREL SALTED      43.00         305        18.50
# 8614   90240  SCALLOP (BAY&SEA) CKD STMD      70.25         111        20.54
# 8615   90480                  SYRUP CANE      26.00         269         0.00
# 8616   90560                   SNAIL RAW      79.20          90        16.10
# 8617   93600            TURTLE GREEN RAW      78.50          89        19.80
#
# ...

# %%
col_names = food_info.columns.tolist()
gram_columns = []

for c in col_names:
    if c.endswith("(g)"):
        gram_columns.append(c)
        
gram_df = food_info[gram_columns]
gram_df.head(3)
# Out:
#    Water_(g)  Protein_(g)  Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  \
# 0      15.87         0.85          81.11     2.11            0.06
# 1      15.87         0.85          81.11     2.11            0.06
# 2       0.24         0.28          99.48     0.00            0.00
#
#    Fiber_TD_(g)  Sugar_Tot_(g)  FA_Sat_(g)  FA_Mono_(g)  FA_Poly_(g)
# 0           0.0           0.06      51.368       21.021        3.043
# 1           0.0           0.06      50.489       23.426        3.012
# 2           0.0           0.00      61.924       28.732        3.694

# %%
water_energy = food_info["Water_(g)"] * food_info["Energ_Kcal"]
print(water_energy[0:5])
# Out:
# 0    11378.79
# 1    11378.79
# 2      210.24
# 3    14970.73
# 4    15251.81
# dtype: float64

# %%
grams_of_protein_per_gram_of_water = food_info["Protein_(g)"] / food_info["Water_(g)"]

grams_of_protein_per_gram_of_water
# Out:
# 0       0.053560
# 1       0.053560
# 2       1.166667
# 3       0.504598
# 4       0.565313
#           ...
# 8613    0.430233
# 8614    0.292384
# 8615    0.000000
# 8616    0.203283
# 8617    0.252229
# Length: 8618, dtype: float64

# %%
miligrams_of_calcium_and_iron = food_info["Calcium_(mg)"] + food_info["Iron_(mg)"]
miligrams_of_calcium_and_iron
# Out:
# 0        24.02
# 1        24.16
# 2         4.00
# 3       528.31
# 4       674.43
#          ...
# 8613     67.40
# 8614     10.58
# 8615     16.60
# 8616     13.50
# 8617    119.40
# Length: 8618, dtype: float64

# %%
protein = food_info["Protein_(g)"] * 2

# %%
fat = food_info["Lipid_Tot_(g)"] * -0.75

# %%
protein
# Out:
# 0        1.70
# 1        1.70
# 2        0.56
# 3       42.80
# 4       46.48
#         ...
# 8613    37.00
# 8614    41.08
# 8615     0.00
# 8616    32.20
# 8617    39.60
# Name: Protein_(g), Length: 8618, dtype: float64

# %%
fat
# Out:
# 0      -60.8325
# 1      -60.8325
# 2      -74.6100
# 3      -21.5550
# 4      -22.2600
#          ...
# 8613   -18.8250
# 8614    -0.6300
# 8615    -0.0000
# 8616    -1.0500
# 8617    -0.3750
# Name: Lipid_Tot_(g), Length: 8618, dtype: float64

# %%
rating = protein + fat
rating
# Out:
# 0      -59.1325
# 1      -59.1325
# 2      -74.0500
# 3       21.2450
# 4       24.2200
#          ...
# 8613    18.1750
# 8614    40.4500
# 8615     0.0000
# 8616    31.1500
# 8617    39.2250
# Length: 8618, dtype: float64

# %%
#Valeur max de la colonne "Energ_kacl"
max_calories = food_info["Energ_Kcal"].max()
max_calories
# Out:
# 902

# %%
max_protein = food_info["Protein_(g)"].max()
normalized_protein = food_info["Protein_(g)"] / max_protein
normalized_protein
# Out:
# 0       0.009624
# 1       0.009624
# 2       0.003170
# 3       0.242301
# 4       0.263134
#           ...
# 8613    0.209466
# 8614    0.232563
# 8615    0.000000
# 8616    0.182292
# 8617    0.224185
# Name: Protein_(g), Length: 8618, dtype: float64

# %%
#créer une nouvelle colonne 
iron_grams = food_info["Iron_(mg)"] / 1000
food_info["Iron_(g)"] = iron_grams
food_info
# Out:
#       NDB_No                   Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 0       1001            BUTTER WITH SALT      15.87         717         0.85
# 1       1002    BUTTER WHIPPED WITH SALT      15.87         717         0.85
# 2       1003        BUTTER OIL ANHYDROUS       0.24         876         0.28
# 3       1004                 CHEESE BLUE      42.41         353        21.40
# 4       1005                CHEESE BRICK      41.11         371        23.24
# ...      ...                         ...        ...         ...          ...
# 8613   83110             MACKEREL SALTED      43.00         305        18.50
# 8614   90240  SCALLOP (BAY&SEA) CKD STMD      70.25         111        20.54
# 8615   90480                  SYRUP CANE      26.00         269         0.00
# 8616   90560                   SNAIL RAW      79.20          90        16.10
# 8617   93600            TURTLE GREEN RAW      78.50          89        19.80
#
# ...

# %%
food_info["Normalized_Protein"] = normalized_protein

# %%
food_info
# Out:
#       NDB_No                   Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 0       1001            BUTTER WITH SALT      15.87         717         0.85
# 1       1002    BUTTER WHIPPED WITH SALT      15.87         717         0.85
# 2       1003        BUTTER OIL ANHYDROUS       0.24         876         0.28
# 3       1004                 CHEESE BLUE      42.41         353        21.40
# 4       1005                CHEESE BRICK      41.11         371        23.24
# ...      ...                         ...        ...         ...          ...
# 8613   83110             MACKEREL SALTED      43.00         305        18.50
# 8614   90240  SCALLOP (BAY&SEA) CKD STMD      70.25         111        20.54
# 8615   90480                  SYRUP CANE      26.00         269         0.00
# 8616   90560                   SNAIL RAW      79.20          90        16.10
# 8617   93600            TURTLE GREEN RAW      78.50          89        19.80
#
# ...

# %%
#Tri par la methode sort_values()
food_info.sort_values("Sodium_(mg)")
# Out:
#       NDB_No                                          Shrt_Desc  Water_(g)  \
# 6470   20061                                   RICE FLOUR WHITE      11.89
# 611     4002                                               LARD       0.00
# 630     4034  OIL SOYBN SALAD OR COOKING (PARTIALLY HYDROGEN...       0.00
# 3663   12058                                         ACORNS RAW      27.90
# 8212   35156                   OIL SPOTTED SEAL (ALASKA NATIVE)       0.25
# ...      ...                                                ...        ...
# 8184   35092               WILLOW LEAVES IN OIL (ALASKA NATIVE)      28.00
# 8185   35093          WILLOW YOUNG LEAVES CHOPD (ALASKA NATIVE)      68.70
# 8195   35139                     SQUASH INDIAN CKD BLD (NAVAJO)      96.21
# 8251   35199       PRICKLY PEARS BRLD (NORTHERN PLAINS INDIANS)      75.83
# 8267   35231               SEA LION STELLER FAT (ALASKA NATIVE)       4.70
#
# ...

# %%
# Tri le dataframe et remplace l'ancien dataframe
food_info.sort_values("Sodium_(mg)", inplace=True, ascending=False)

# %%
food_info
# Out:
#       NDB_No                                     Shrt_Desc  Water_(g)  \
# 276     2047                                    SALT TABLE       0.20
# 5814   18372                  LEAVENING AGENTS BAKING SODA       0.20
# 6192   19225               DESSERTS RENNIN TABLETS UNSWTND       6.50
# 1242    6075             SOUP BF BROTH OR BOUILLON PDR DRY       3.27
# 1245    6081                    SOUP CHICK BROTH CUBES DRY       2.50
# ...      ...                                           ...        ...
# 8184   35092          WILLOW LEAVES IN OIL (ALASKA NATIVE)      28.00
# 8185   35093     WILLOW YOUNG LEAVES CHOPD (ALASKA NATIVE)      68.70
# 8195   35139                SQUASH INDIAN CKD BLD (NAVAJO)      96.21
# 8251   35199  PRICKLY PEARS BRLD (NORTHERN PLAINS INDIANS)      75.83
# 8267   35231          SEA LION STELLER FAT (ALASKA NATIVE)       4.70
#
#       Energ_Kcal  Protein_(g)  Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  \
# ...
